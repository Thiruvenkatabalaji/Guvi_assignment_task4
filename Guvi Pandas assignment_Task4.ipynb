# %% [markdown]
# # Assessment

# %%
#import necessary libraries

import pandas as pd
import numpy as np

# %%
import pandas as pd

df1 = pd.read_csv("C:\\Users\\thiru\\OneDrive\\Documents\\Guvi assignement_Task_4\\college_1.csv")
df1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
df2= pd.read_csv("C:\\Users\\thiru\\OneDrive\\Documents\\Guvi assignement_Task_4\\college_2.csv")
df2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %%
df1.columns
# Out:
# Index(['Name', 'python', 'mysql', 'Previous Geekions', 'CodeKata Score',
#        'Department', 'Rising'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Name', 'python', 'python_en', 'mysql', 'computational_thinking',
#        'Previous Geekions', 'CodeKata Score', 'Department', 'Rising'],
#       dtype='object')

# %%
frames = [df1,df2]
results =pd.concat(frames)
results
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data= pd.DataFrame(results)
data.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %%
data.rename(columns={"CodeKata Score": "Codekata_score"},inplace=True)

# %%
data
# Out:
#              Name  python  mysql  Previous Geekions  Codekata_score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
data.head()
# Out:
#           Name  python  mysql  Previous Geekions  Codekata_score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %%
#Exceed expectation.
codekata_score = data.query("Codekata_score > 15000")
codekata_score.to_csv("C:\\Users\\thiru\\OneDrive\\Documents\\Guvi assignement_Task_4\\Exceeded expection.csv")

# %%
#Reached_expectation
data.query("10000 < Codekata_score < 15000") # codekata score
# Out:
#                 Name  python  mysql  Previous Geekions  Codekata_score  \
# 3        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 3           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 3                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %%
#Reached expectation
reached_expectation = data.query("10000 < Codekata_score < 15000")
reached_expectation.to_csv("C:\\Users\\thiru\\OneDrive\\Documents\\Guvi assignement_Task_4\\Reached_expections.csv")

# %%
#Needs imporvement
need_improvement = data.query("7000 < Codekata_score < 10000")
need_improvement.to_csv("C:\\Users\\thiru\\OneDrive\\Documents\\Guvi assignement_Task_4\\Needs_improvement.csv")

# %%
#Unsatisfactory
unsatisfactory = data.query("Codekata_score < 7000")
unsatisfactory.to_csv("C:\\Users\\thiru\\OneDrive\\Documents\\Guvi assignement_Task_4\\Unsatisfactory.csv")

# %%
#Average of previous week geekoins

print("Average Previous Geekoins:",round(data["Previous Geekions"].mean(),3))
print("Average CodeKata Score:",round(data["Codekata_score"].mean(),3))
# Out:
# Average Previous Geekoins: 3842.353
# Average CodeKata Score: 4051.765

# %%
#No.of.students participated

print("Total No.of.students participated:",data["Name"].count())
# Out:
# Total No.of.students participated: 119

# %%
data.max(axis=0)
# Out:
# Name                                              yaser ahamed.A
# python                                                     100.0
# mysql                                                      100.0
# Previous Geekions                                          24500
# Codekata_score                                             24500
# Department                Electronics and Electrical Engineering
# Rising                                                      3140
# python_en                                                  100.0
# computational_thinking                                      39.0
# dtype: object

# %%
Top_rising_star =  data.sort_values(by=["Rising"],ascending=False)

# Top_rising_star.head(3)
Top_rising_star["Name"].head(3)
# Out:
# 8              shifak N
# 18       Narasimhan Y L
# 2     Ganesh Ramkumar R
# Name: Name, dtype: object

# %%
#rising star

Top_rising_star =  data.sort_values(by=["Rising"],ascending=False)
Top_rising_star.head(3)
# Out:
#                  Name  python  mysql  Previous Geekions  Codekata_score  \
# 8            shifak N    58.0    0.0               5180            8320
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 18        Computer Science and Engineering    2000       -1.0
# 2         Computer Science and Engineering    2000       55.0
#
#     computational_thinking
# 8                      0.0
# 18                     0.0
# 2                      6.0

# %%
#shining star

Top_geekoins_cand =  data.sort_values(by=["Previous Geekions"],ascending=False)
# Top_geekoins_cand.head(3)
Top_geekoins_cand["Name"].head(3)
# Out:
# 0      A.Dharani
# 1    V.JEEVITHA
# 2    HEMAVATHI.R
# Name: Name, dtype: object

# %%
#shining star

Top_geekoins_cand =  data.sort_values(by=["Previous Geekions"],ascending=False)
Top_geekoins_cand.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  Codekata_score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %%
from matplotlib import pyplot as plt
data.groupby(["Department"]).sum().plot(kind="pie",y="Codekata_score")
plt.legend(title = "Departments:")
plt.show()

# %%
from matplotlib import pyplot as plt
x = data["Department"]
y = data["Codekata_score"]

plt.barh(x,y)
plt.xlabel("Codekata_scroe")
plt.ylabel("Departments")
plt.title("Leaders")
plt.show()

# %%
from matplotlib import pyplot as plt

data_group = data.groupby(["Department"])["Codekata_score"].max()

data_group.plot(kind="bar", title= "Department wise toppers",xlabel="\n Department", ylabel= "Codekata_score",figsize=(12,5),color = ["red","green","blue"], edgecolor='black')
# plt.legend(loc="upper right")
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Computer Science and Engineering'),
#   Text(1, 0, 'Electronics and Communication Engineering'),
#   Text(2, 0, 'Electronics and Electrical Engineering')])

# %%
import matplotlib.pyplot as plt

x =
